# %%
import tiktoken

# Initialize the tokenizer
tokenizer = tiktoken.get_encoding("cl100k_base")

# Example text to tokenize
text = "Which is the capital city of the India?"

# Tokenize the text
tokens = tokenizer.encode(text)
print(tokens)

for token in tokens:
    # Decode each token back to text
    decoded_token = tokenizer.decode([token])
    print(f"Token: {token}, Decoded: {decoded_token}")

# Decode the tokens back to text
#decoded_text = tokenizer.decode(tokens)
#print(decoded_text)
# Out:
# [23956, 374, 279, 6864, 3363, 315, 6890, 30]
# Token: 23956, Decoded: Which
# Token: 374, Decoded:  is
# Token: 279, Decoded:  the
# Token: 6864, Decoded:  capital
# Token: 3363, Decoded:  city
# Token: 315, Decoded:  of
# Token: 6890, Decoded:  India
# Token: 30, Decoded: ?
