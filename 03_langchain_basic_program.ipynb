# %%
from langchain_ollama import ChatOllama
from langchain_openai import ChatOpenAI
model = ChatOllama(model="gpt-oss:120b-cloud")

# %%
response = model.invoke("Which is the capital of India?")
print(type(response))
print(response)
